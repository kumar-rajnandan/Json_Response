# %%
import requests
import pandas as pd
import polyline

# %%
url = 'https://maps.googleapis.com/maps/api/directions/json?origin=13.047437,78.476334&destination=13.061761,78.526941&key=AIzaSyB-7V8xFUmJJ6Eh48jWd5-5K4vOEcYpDqU&alternatives=false&departure_time=now&mode=driving&computeAlternativeRoutes=True'
response = requests.get(url)
data = response.json()
print("KEYS\n", data.keys(), "\n")
# Out:
# KEYS
#  dict_keys(['geocoded_waypoints', 'routes', 'status'])

# %%
def decode_points(points_str, precision):
    decoded_points = polyline.decode(points_str, precision)
    return decoded_points

# %%
data['routes'][0].keys()
# Out:
# dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order'])

# %%
for steps in data['routes'][0]['legs']:
    df = pd.DataFrame(steps['steps'])
    selected_columns = ['distance', 'duration', 'end_location', 'start_location', 'polyline', 'travel_mode']
    df_selected = df[selected_columns]
    df_selected['polyline'] = df_selected['polyline'].apply(lambda x: decode_points(x['points'], 5))
    print(df_selected.to_csv("Root_Steps.csv"))
# Out:
# None
# <ipython-input-7-859d09a30b68>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_selected['polyline'] = df_selected['polyline'].apply(lambda x: decode_points(x['points'], 5))

# %%
data['routes'][0].keys()
# Out:
# dict_keys(['bounds', 'copyrights', 'legs', 'overview_polyline', 'summary', 'warnings', 'waypoint_order'])

# %%
data['routes'][0]
# Out:
# {'bounds': {'northeast': {'lat': 13.0715313, 'lng': 78.52674499999999},
#   'southwest': {'lat': 13.0474183, 'lng': 78.47590699999999}},
#  'copyrights': 'Map data ©2024',
#  'legs': [{'distance': {'text': '9.1 km', 'value': 9129},
#    'duration': {'text': '21 mins', 'value': 1236},
#    'duration_in_traffic': {'text': '20 mins', 'value': 1191},
#    'end_address': 'Unnamed Road, Thota Kanuma, Andhra Pradesh 517415, India',
#    'end_location': {'lat': 13.0615669, 'lng': 78.52674499999999},
#    'start_address': '2FWG+PGQ, Jounipalle, Andhra Pradesh 517415, India',
#    'start_location': {'lat': 13.0474183, 'lng': 78.4764405},
#    'steps': [{'distance': {'text': '0.1 km', 'value': 96},
#      'duration': {'text': '1 min', 'value': 16},
#      'end_location': {'lat': 13.0482271, 'lng': 78.47675149999999},
#      'html_instructions': 'Head <b>north</b>',
#      'polyline': {'points': 'kisnAwl~}MiA]wA_@'},
#      'start_location': {'lat': 13.0474183, 'lng': 78.4764405},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '0.1 km', 'value': 98},
#      'duration': {'text': '1 min', 'value': 21},
#      'end_location': {'lat': 13.0485532, 'lng': 78.47590699999999},
#      'html_instructions': 'Turn <b>left</b>',
#      'maneuver': 'turn-left',
#      'polyline': {'points': 'mnsnAun~}M?@U|@]hAK\\'},
#      'start_location': {'lat': 13.0482271, 'lng': 78.47675149999999},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '2.3 km', 'value': 2298},
#      'duration': {'text': '7 mins', 'value': 408},
#      'end_location': {'lat': 13.0685049, 'lng': 78.4776674},
#      'html_instructions': 'Turn <b>right</b> at the 1st cross street',
#      'maneuver': 'turn-right',
#      'polyline': {'points': 
',
#      'maneuver': 'turn-right',
#      'polyline': {'points': '_|wnAmdh~MRH'},
#      'start_location': {'lat': 13.0708821, 'lng': 78.5263118},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '0.3 km', 'value': 284},
#      'duration': {'text': '1 min', 'value': 43},
#      'end_location': {'lat': 13.0682988, 'lng': 78.52644889999999},
#      'html_instructions': 'Slight <b>left</b> at SHRI RAMALAYAM TEMPLE',
#      'maneuver': 'turn-slight-left',
#      'polyline': {'points': 'k{wnAcdh~MRAz@Dp@@`@?`BYj@Kd@IXIHCF?D?F@NFLDDBB?D?D@HA^A'},
#      'start_location': {'lat': 13.0707823, 'lng': 78.5262552},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '0.6 km', 'value': 616},
#      'duration': {'text': '2 mins', 'value': 116},
#      'end_location': {'lat': 13.0632139, 'lng': 78.52505719999999},
#      'html_instructions': 'Slight <b>right</b><div style="font-size:0.9em">Pass by Syed imran (on the left)</div>',
#      'maneuver': 'turn-slight-right',
#      'polyline': {'points': '{kwnAieh~MD@B@NDJBJBLBLFLFHFJBFBJBNDLDNBD@D@@?F@NBVDTBV@XDTD@?VFH@LBP@L?L@VCVCHCJATCNCJENENCPCP?FAJ@R@T?H?H@NBRDN@RBNDH@FBFDFFHHFHFLDHDHDHDBFBFDNFLDLDJDLDF@FBFBHHHHLF'},
#      'start_location': {'lat': 13.0682988, 'lng': 78.52644889999999},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '0.2 km', 'value': 188},
#      'duration': {'text': '1 min', 'value': 40},
#      'end_location': {'lat': 13.062006, 'lng': 78.5262561},
#      'html_instructions': 'Turn <b>left</b>',
#      'maneuver': 'turn-left',
#      'polyline': {'points': 'alvnAs|g~MjByBJMLOPQNOHGJIZQTQ'},
#      'start_location': {'lat': 13.0632139, 'lng': 78.52505719999999},
#      'travel_mode': 'DRIVING'},
#     {'distance': {'text': '72 m', 'value': 72},
#      'duration': {'text': '1 min', 'value': 14},
#      'end_location': {'lat': 13.0615669, 'lng': 78.52674499999999},
#      'html_instructions': 'Continue straight<div style="font-size:0.9em">Destination will be on the left</div>',
#      'maneuver': 'straight',
#      'polyline': {'points': 'qdvnAcdh~MBGDEBE@AHIHIRQLQNO@A'},
#      'start_location': {'lat': 13.062006, 'lng': 78.5262561},
#      'travel_mode': 'DRIVING'}],
#    'traffic_speed_entry': [],
#    'via_waypoint': []}],
#  'overview_polyline': {'points': 'kisnAwl~}MaD}@U~@i@fBgB_AqEiBeAWkCg@qBe@iBa@o@KkBCcA@{CJs@MaAYg@IwAEm@CuA?aB?uAIcAMw@O_@Ag@Hs@Vg@NoAV_AFaCAuBNcDh@y@Bs@AgBKcAK_A@cA@mATuAT}@Xi@J_@Ji@Re@BkBS_AGy@CkAWk@OeBa@qAWuBg@MIR_At@sDVsB`@iAXkAJi@HiAPuBN{AXsAPoA@a@@qADwBLgDJ}@Km@[qAYmBOqAIiB@{BEw@@c@JeATuADk@Bm@CW[oBLeCTiBFgAHoDFgANuAPwAL}ANyC@}AMmAa@}BsAsFk@gCIWHUDU@WG_@Qi@AWBKp@cD`@}CHiA?g@Go@Yy@gAmCUy@IgAEmBMgAm@_DWeAYs@}AwCwAyCk@}Ao@yBS}@WqBg@iDAqAD{AFaHI_JAsJAuFAeAGcAWoA]aAc@q@{AsCWq@O]AQ?]h@uBl@sChAsERoADoAAkACi@k@eEUsAAu@?]Hc@D[RHRAz@DrA@lCe@~@SPCL@\\LTDh@CHBt@Pp@Zp@RbBVp@FVD`ANZ@n@Gz@MZK`@Gx@@x@DfAPPDNLPRLVJRLFr@Xh@Ph@^vCiDXWf@[TQBGHKh@g@^c@'},
#  'summary': '',
#  'warnings': [],
#  'waypoint_order': []}

# %%
overview_polyline = data['routes'][0]['overview_polyline']
overview_polyline
# Out:
# {'points': 'kisnAwl~}MaD}@U~@i@fBgB_AqEiBeAWkCg@qBe@iBa@o@KkBCcA@{CJs@MaAYg@IwAEm@CuA?aB?uAIcAMw@O_@Ag@Hs@Vg@NoAV_AFaCAuBNcDh@y@Bs@AgBKcAK_A@cA@mATuAT}@Xi@J_@Ji@Re@BkBS_AGy@CkAWk@OeBa@qAWuBg@MIR_At@sDVsB`@iAXkAJi@HiAPuBN{AXsAPoA@a@@qADwBLgDJ}@Km@[qAYmBOqAIiB@{BEw@@c@JeATuADk@Bm@CW[oBLeCTiBFgAHoDFgANuAPwAL}ANyC@}AMmAa@}BsAsFk@gCIWHUDU@WG_@Qi@AWBKp@cD`@}CHiA?g@Go@Yy@gAmCUy@IgAEmBMgAm@_DWeAYs@}AwCwAyCk@}Ao@yBS}@WqBg@iDAqAD{AFaHI_JAsJAuFAeAGcAWoA]aAc@q@{AsCWq@O]AQ?]h@uBl@sChAsERoADoAAkACi@k@eEUsAAu@?]Hc@D[RHRAz@DrA@lCe@~@SPCL@\\LTDh@CHBt@Pp@Zp@RbBVp@FVD`ANZ@n@Gz@MZK`@Gx@@x@DfAPPDNLPRLVJRLFr@Xh@Ph@^vCiDXWf@[TQBGHKh@g@^c@'}

# %%
points_value = overview_polyline.get('points', None)
overall_polyline = polyline.decode(points_value, 5)
overall_polyline
# Out:
# [(13.04742, 78.47644),
#  (13.04823, 78.47675),
#  (13.04834, 78.47643),
#  (13.04855, 78.47591),
#  (13.04907, 78.47623),
#  (13.05012, 78.47676),
#  (13.05047, 78.47688),
#  (13.05117, 78.47708),
#  (13.05174, 78.47727),
#  (13.05227, 78.47744),
#  (13.05251, 78.4775),
#  (13.05305, 78.47752),
#  (13.05339, 78.47751),
#  (13.05417, 78.47745),
#  (13.05443, 78.47752),
#  (13.05476, 78.47765),
#  (13.05496, 78.4777),
#  (13.0554, 78.47773),
#  (13.05563, 78.47775),
#  (13.05606, 78.47775),
#  (13.05655, 78.47775),
#  (13.05698, 78.4778),
#  (13.05732, 78.47787),
#  (13.0576, 78.47795),
#  (13.05776, 78.47796),
#  (13.06856, 78.50582),
#  (13.06903, 78.50658),
#  (13.06947, 78.50735),
#  (13.06969, 78.50782),
#  (13.06993, 78.50843),
#  (13.07003, 78.50874),
#  (13.07015, 78.50931),
#  (13.07035, 78.51016),
#  (13.07036, 78.51057),
#  (13.07033, 78.51103),
#  (13.07029, 78.51248),
#  (13.07034, 78.51424),
#  (13.07035, 78.5161),
#  (13.07036, 78.51733),
#  (13.07037, 78.51768),
#  (13.07041, 78.51802),
#  (13.07053, 78.51842),
#  (13.07068, 78.51875),
#  (13.07086, 78.519),
#  (13.07132, 78.51974),
#  (13.07144, 78.51999),
#  (13.07152, 78.52014),
#  (13.07153, 78.52023),
#  (13.07153, 78.52038),
#  (13.07132, 78.52097),
#  (13.07109, 78.52171),
#  (13.07072, 78.52277),
#  (13.07062, 78.52317),
#  (13.07059, 78.52357),
#  (13.0706, 78.52395),
#  (13.07062, 78.52416),
#  (13.07084, 78.52515),
#  (13.07095, 78.52557),
#  (13.07096, 78.52584),
#  (13.07096, 78.52599),
#  (13.07091, 78.52617),
#  (13.07088, 78.52631),
#  (13.07078, 78.52626),
#  (13.07068, 78.52627),
#  (13.07038, 78.52624),
#  (13.06996, 78.52623),
#  (13.06925, 78.52642),
#  (13.06893, 78.52652),
#  (13.06884, 78.52654),
#  (13.06877, 78.52653),
#  (13.06862, 78.52646),
#  (13.06851, 78.52643),
#  (13.0683, 78.52645),
#  (13.06825, 78.52643),
#  (13.06798, 78.52634),
#  (13.06773, 78.5262),
#  (13.06748, 78.5261),
#  (13.06698, 78.52598),
#  (13.06673, 78.52594),
#  (13.06661, 78.52591),
#  (13.06628, 78.52583),
#  (13.06614, 78.52582),
#  (13.0659, 78.52586),
#  (13.0656, 78.52593),
#  (13.06546, 78.52599),
#  (13.06529, 78.52603),
#  (13.065, 78.52602),
#  (13.06471, 78.52599),
#  (13.06435, 78.5259),
#  (13.06426, 78.52587),
#  (13.06418, 78.5258),
#  (13.06409, 78.5257),
#  (13.06402, 78.52558),
#  (13.06396, 78.52548),
#  (13.06389, 78.52544),
#  (13.06363, 78.52531),
#  (13.06342, 78.52522),
#  (13.06321, 78.52506),
#  (13.06245, 78.52591),
#  (13.06232, 78.52603),
#  (13.06212, 78.52617),
#  (13.06201, 78.52626),
#  (13.06199, 78.5263),
#  (13.06194, 78.52636),
#  (13.06173, 78.52656),
#  (13.06157, 78.52674)]

# %%
odf = pd.DataFrame(overall_polyline)
odf
# Out:
#             0         1
# 0    13.04742  78.47644
# 1    13.04823  78.47675
# 2    13.04834  78.47643
# 3    13.04855  78.47591
# 4    13.04907  78.47623
# ..        ...       ...
# 196  13.06201  78.52626
# 197  13.06199  78.52630
# 198  13.06194  78.52636
# 199  13.06173  78.52656
# 200  13.06157  78.52674
#
# [201 rows x 2 columns]
